# %% [markdown]
# ---
#
# ## Data Analysis
#
# - This file differs from [2_data_analysis_1_base_data.ipynb](2_data_analysis_1_base_data.ipynb) in that it:
#     - scales the base cleaned data created in [1_data_cleaning.ipynb](1_data_cleaning.ipynb).
#
# Source dataset: 247076 rows × 37 columns
# Processed and analyzed dataset: 247076 rows × 37 columns
#
# ---

# %%
# package imports go here
import pandas as pd
import numpy as np
import fastparquet as fp
import os
import sys
import pickle
import matplotlib.pyplot as plt
import importlib
import config

sys.path.insert(1, config.package_path)
import ml_analysis as mlanlys
import ml_clean_feature as mlclean

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ---
#
# ## 1. Read the cleaned dataset from file
#
# ---

# %%
# reload any changes to Config Settings
importlib.reload(config)

year                        = config.year

clean_file                  = config.clean_file

print(f"Year:                        {year}")
print(f"Clean File:                  {clean_file}")
# Out:
# Year:                        2021
# Clean File:                  data/brfss_2021_clean.parquet.gzip

# %%
# Read final cleaned dataset from parquet file
df = pd.read_parquet(clean_file, engine="fastparquet")

# %%
diabetes_labels = df.columns

# %%
df.shape
# Out:
# (247076, 37)

# %% [markdown]
# ---
#
# ## 2. Prepare the dataset for analysis
#
# - Split the dataset into features and labels.
# - Split the dataset into training and testing sets.
# - Scale the dataset
#
# ---

# %%
from sklearn.datasets import make_regression, make_swiss_roll
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
# reload any changes to mlanlys
importlib.reload(mlanlys)

target = 'diabetes'
# Dictionary defining modification to be made to the base dataset
operation_dict = {  'target_column'     :  target,
                    'convert_to_binary' :  True,
                    'scaler'            : 'standard', # options: none, standard, minmax
                    'random_sample'     : 'none'      # options: none, undersample, oversample
                    }

# This insures that df if not modified during the call to modify_base_dataset()
df_modified = df.copy()

# Modify the base dataset
# data is returned where: X_train, X_test, y_train, y_test = data
prepared_data = mlanlys.modify_base_dataset(df_modified, operation_dict)
# Out:
# Base Dataset Modifications in Process
# -------------------------------------
# **Operation:target_column  diabetes
# **Operation:convert_to_binary  True
#   -- Converting dataset to binary (0,1) from (0,1,2)
#
#
# ****Cleaning Feature: diabetes
#   Initial Unique features in [diabetes]:  [0. 1. 2.]
#   values_to_drop: ********* NO Parameters were specified *********
#   translate: {1: 0, 2: 1}
#   scale: ********* NO Parameters were specified *********
#   FINAL Unique features in [diabetes]:  [0. 1.]
# **Operation:scaler  standard
#   -- Performing train_test_split on dataframe with target:'diabetes'
#      -- Run automatically before scalar or random_sample operations
#   -- Performing StandardScaler on X_train: Updates X_train, y_test
# **Operation:random_sample  none
#
# Dataframe, Train Test Summary
# -----------------------------
# Dataframe: (247076, 37)  Data:4, X_train:185307, y_train:185307, X_test:61769, y_test:61769
# ValueCounts:   y_train: len:2   0: 160529   1: 24778
# ValueCounts:   y_test : len:2   0:  53514   1:  8255

# %%
# Print some statistics about the original df and the modified dataframe
print(f"Original Dataframe")
print(f"------------------")
print(f"df.shape: {df.shape}")
print(f"df[{target}].value_counts:  {df[target].value_counts()}")

print(f"\nModified Dataframe")
print(f"------------------")
print(f"df_modified.shape: {df_modified.shape}")
print(f"df_modified[{target}].value_counts:  {df_modified[target].value_counts()}")
# Out:
# Original Dataframe
# ------------------
# df.shape: (247076, 37)
# df[diabetes].value_counts:  diabetes
# 0.0    208389
# 2.0     33033
# 1.0      5654
# Name: count, dtype: int64
#
# Modified Dataframe
# ------------------
# df_modified.shape: (247076, 37)
# df_modified[diabetes].value_counts:  diabetes
# 0.0    214043
# 1.0     33033
# Name: count, dtype: int64

# %%
X_train, X_test, y_train, y_test = prepared_data
print(f"Dataframe: {df_modified.shape}  Data:{len(prepared_data)}, X_train:{len(X_train)}, y_train:{len(y_train)}, X_test:{len(X_test)}, y_test:{len(y_test)}")
# Out:
# Dataframe: (247076, 37)  Data:4, X_train:185307, y_train:185307, X_test:61769, y_test:61769

# %%
y_train.value_counts()
# Out:
# diabetes
# 0.0    160529
# 1.0     24778
# Name: count, dtype: int64

# %%
y_test.value_counts()
# Out:
# diabetes
# 0.0    53514
# 1.0     8255
# Name: count, dtype: int64

# %% [markdown]
# ---
#
# ## 3. Optimization
#
# ---
#
# #### 3.1 Pre-optimization metric results
#
# - The summary report of the metrics for all pre-optimization runs is here:  [performance_report.txt](reports/performance_report.txt)
# - The details of the runs are contained in these file:
#     - [base_dataset_detailed_performance_report.txt](reports/base_dataset_detailed_performance_report.txt)
#     - [binary_dataset_detailed_performance_report.txt](reports/binary_dataset_detailed_performance_report.txt)
#     - [minmax_scaled_dataset_detailed_performance_report.txt](reports/minmax_scaled_dataset_detailed_performance_report.txt)
#     - [randomoversample_dataset_detailed_performance_report.txt](reports/randomoversample_dataset_detailed_performance.txt)
#     - [cluster_dataset_detailed_performance_report.txt](reports/cluster_dataset_detailed_performance_report.txt)
#     - [randomundersampled_dataset_detailed_performance_report.txt](reports/randomundersampled_dataset_detailed_performance_report.txt)
#     - [minmax_scaled_dataset_detailed_performance_report.txt](reports/minmax_scaled_dataset_detailed_performance_report.txt)
#     - [smoteen_dataset_detailed_performance_report.txt](reports/smoteen_dataset_detailed_performance_report.txt)
#     - [standard_scaled_dataset_detailed_performance_report.txt](reports/standard_scaled_dataset_detailed_performance_report.txt)
#     - [smote_dataset_detailed_performance_report.txt](reports/smote_dataset_detailed_performance_report.txt)
#
# #### 3.2 Optimization Dataset used
#
# **Note:**  Modify the dataset as desired in Section 2.
# <br><br>
# Currently the dataset uses the Base dataset for 2015 with the following modifications:
# - **Target converted to Binary**:  (0,1) from (0,1,2).
#     - Base:  0: No diabetes, 1: Pre-diabetes, 2: have diabetes
#     - binary: 0: No diabetes/pre-diabetes, 1: have diabetes
# - Scaled the data with **StandardScaler**
# - Resampled the data with **RandomUnderSampler**

# %% [markdown]
# #### 3.2 Optimization Analysis

# %%
# Note:  Modify the dataset as desired in Section 2.
# Currently the dataset uses the Base dataset for 2015 with the following modifications

# %%
# Dataset summary:
X_train, X_test, y_train, y_test = prepared_data

print(f"Dataset Lens, X_train:{len(X_train)}, y_train:{len(y_train)}, X_test:{len(X_test)}, y_test:{len(y_test)}")
print(f"y_train value_counts: {y_train.value_counts()}")
print(f"y_test value_counts: {y_test.value_counts()}")
# Out:
# Dataset Lens, X_train:185307, y_train:185307, X_test:61769, y_test:61769
# y_train value_counts: diabetes
# 0.0    160529
# 1.0     24778
# Name: count, dtype: int64
# y_test value_counts: diabetes
# 0.0    53514
# 1.0     8255
# Name: count, dtype: int64

# %% [markdown]
# ##### 3.2.1 Perform Optimization:
#
# - Datamodel:  2015 Diabetes Data Set
# - Optimization approaches: LogisticRegression RandomizedSearchCV

# %%
df_modified_sample = df_modified.head(100)

from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import uniform
from sklearn.metrics import classification_report, accuracy_score

# Define the parameter grid
param_distributions = {
    'C': uniform(loc=0, scale=4),  # Regularization parameter
    'penalty': ['l1', 'l2'],     # Regularization type
    'solver': ['newton-cg', 'lbfgs', 'sag', 'saga']  # Solvers that support L2 regularization
}

# Initialize the Logistic Regression model
log_reg = LogisticRegression(max_iter=5000)

# Initialize the RandomizedSearchCV
random_search = RandomizedSearchCV(
    log_reg, 
    param_distributions=param_distributions, 
    n_iter=100,  # Number of parameter settings that are sampled
    cv=5,        # 5-fold cross-validation
    verbose=3,   # Verbosity mode
    n_jobs=-1,   # Use all available cores
    random_state=42  # Seed for reproducibility
)

# Fit the model
random_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV 2/5] END C=1.49816047538945, penalty=l1, solver=sag;, score=nan total time=   0.1s
# [CV 3/5] END C=1.49816047538945, penalty=l1, solver=sag;, score=nan total time=   0.1s
# [CV 1/5] END C=1.49816047538945, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 5/5] END C=1.49816047538945, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 1/5] END C=2.9279757672456204, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 2/5] END C=2.9279757672456204, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 4/5] END C=1.49816047538945, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 4/5] END C=2.9279757672456204, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 2/5] END C=0.6240745617697461, penalty=l1, solver=sag;, score=nan total time=   0.1s
# [CV 3/5] END C=0.6240745617697461, penalty=l1, solver=sag;, score=nan total time=   0.1s
# [CV 5/5] END C=0.6240745617697461, penalty=l1, solver=sag;, score=nan total time=   0.1s
# [CV 3/5] END C=2.9279757672456204, penalty=l1, solver=newton-cg;, score=nan total time=   0.1s[CV 1/5] END C=0.6240745617697461, penalty=l1, solver=sag;, score=nan total time=   0.2s
#
# [CV 5/5] END C=2.9279757672456204, penalty=l1, solver=newton-cg;, score=nan total time=   0.1s
# [CV 4/5] END C=0.6240745617697461, penalty=l1, solver=sag;, score=nan total time=   0.1s
# [CV 1/5] END C=3.329770563201687, penalty=l2, solver=lbfgs;, score=0.869 total time=   0.5s
# [CV 1/5] END C=0.7272998688284025, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 2/5] END C=3.329770563201687, penalty=l2, solver=lbfgs;, score=0.869 total time=   0.6s
# [CV 3/5] END C=3.329770563201687, penalty=l2, solver=lbfgs;, score=0.868 total time=   0.6s
# [CV 2/5] END C=0.7272998688284025, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 4/5] END C=3.329770563201687, penalty=l2, solver=lbfgs;, score=0.869 total time=   0.6s
# [CV 5/5] END C=3.329770563201687, penalty=l2, solver=lbfgs;, score=0.871 total time=   0.6s
# [CV 3/5] END C=0.7272998688284025, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 4/5] END C=0.7272998688284025, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 5/5] END C=0.7272998688284025, penalty=l1, solver=newton-cg;, score=nan total time=   0.1s
# [CV 1/5] END C=0.23233444867279784, penalty=l2, solver=newton-cg;, score=0.869 total time=   1.2s
# [CV 2/5] END C=0.23233444867279784, penalty=l2, solver=newton-cg;, score=0.869 total time=   1.1s
# [CV 3/5] END C=0.23233444867279784, penalty=l2, solver=newton-cg;, score=0.868 total time=   1.2s
# [CV 4/5] END C=0.23233444867279784, penalty=l2, solver=newton-cg;, score=0.869 total time=   1.1s
# [CV 1/5] END C=1.727780074568463, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 3/5] END C=1.727780074568463, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 2/5] END C=1.727780074568463, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 4/5] END C=1.727780074568463, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 5/5] END C=1.727780074568463, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 5/5] END C=0.23233444867279784, penalty=l2, solver=newton-cg;, score=0.871 total time=   1.2s
# [CV 2/5] END C=1.216968971838151, penalty=l2, solver=newton-cg;, score=0.869 total time=   1.0s
# [CV 3/5] END C=1.216968971838151, penalty=l2, solver=newton-cg;, score=0.868 total time=   1.0s
# [CV 5/5] END C=1.216968971838151, penalty=l2, solver=newton-cg;, score=0.871 total time=   1.0s
# [CV 4/5] END C=1.216968971838151, penalty=l2, solver=newton-cg;, score=0.869 total time=   1.0s
# [CV 1/5] END C=1.216968971838151, penalty=l2, solver=newton-cg;, score=0.869 total time=   1.3s
# [CV 1/5] END C=0.08233797718320979, penalty=l2, solver=saga;, score=0.869 total time=   3.0s
# [CV 1/5] END C=1.8242799368681437, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END C=1.8242799368681437, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END C=1.8242799368681437, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END C=1.8242799368681437, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END C=1.8242799368681437, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END C=0.08233797718320979, penalty=l2, solver=saga;, score=0.869 total time=   3.2s
# [CV 3/5] END C=0.08233797718320979, penalty=l2, solver=saga;, score=0.868 total time=   3.3s
# [CV 4/5] END C=0.08233797718320979, penalty=l2, solver=saga;, score=0.869 total time=   3.3s
# [CV 5/5] END C=0.08233797718320979, penalty=l2, solver=saga;, score=0.871 total time=   3.2s
# [CV 4/5] END C=2.404460046972835, penalty=l2, solver=sag;, score=0.869 total time=   3.5s
# [CV 1/5] END C=2.36965827544817, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 2/5] END C=2.36965827544817, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 3/5] END C=2.36965827544817, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 4/5] END C=2.36965827544817, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 5/5] END C=2.36965827544817, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 1/5] END C=2.4301794076057535, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 2/5] END C=2.4301794076057535, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 3/5] END C=2.4301794076057535, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 4/5] END C=2.4301794076057535, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 3/5] END C=2.404460046972835, penalty=l2, solver=sag;, score=0.868 total time=   3.8s
# [CV 5/5] END C=2.4301794076057535, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 2/5] END C=2.404460046972835, penalty=l2, solver=sag;, score=0.869 total time=   4.1s
# [CV 4/5] END C=2.447411578889518, penalty=l2, solver=saga;, score=0.869 total time=   2.5s
# [CV 5/5] END C=2.447411578889518, penalty=l2, solver=saga;, score=0.871 total time=   2.4s
# [CV 5/5] END C=2.404460046972835, penalty=l2, solver=sag;, score=0.871 total time=   4.1s
# [CV 1/5] END C=2.447411578889518, penalty=l2, solver=saga;, score=0.869 total time=   2.9s
# [CV 3/5] END C=2.447411578889518, penalty=l2, solver=saga;, score=0.868 total time=   2.9s
# [CV 1/5] END C=3.8625281322982374, penalty=l2, solver=lbfgs;, score=0.869 total time=   0.4s
# [CV 3/5] END C=3.8625281322982374, penalty=l2, solver=lbfgs;, score=0.868 total time=   0.4s
# [CV 2/5] END C=2.447411578889518, penalty=l2, solver=saga;, score=0.869 total time=   3.4s
# [CV 2/5] END C=3.8625281322982374, penalty=l2, solver=lbfgs;, score=0.869 total time=   0.6s
# [CV 1/5] END C=1.2184550766934827, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END C=0.26020637194111806, penalty=l2, solver=newton-cg;, score=0.869 total time=   1.1s
# [CV 1/5] END C=2.404460046972835, penalty=l2, solver=sag;, score=0.869 total time=   5.0s
# [CV 2/5] END C=1.2184550766934827, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END C=3.8625281322982374, penalty=l2, solver=lbfgs;, score=0.869 total time=   0.5s
# [CV 3/5] END C=1.2184550766934827, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END C=1.2184550766934827, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END C=1.2184550766934827, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END C=0.26020637194111806, penalty=l2, solver=newton-cg;, score=0.868 total time=   1.0s
# [CV 2/5] END C=0.26020637194111806, penalty=l2, solver=newton-cg;, score=0.869 total time=   1.2s
# [CV 5/5] END C=0.26020637194111806, penalty=l2, solver=newton-cg;, score=0.871 total time=   1.1s
# [CV 4/5] END C=0.26020637194111806, penalty=l2, solver=newton-cg;, score=0.869 total time=   1.2s
# [CV 5/5] END C=3.8625281322982374, penalty=l2, solver=lbfgs;, score=0.871 total time=   0.6s
# [CV 1/5] END C=1.1685785941408726, penalty=l2, solver=sag;, score=0.869 total time=   3.9s
# [CV 2/5] END C=1.1685785941408726, penalty=l2, solver=sag;, score=0.869 total time=   4.1s
# [CV 3/5] END C=1.1685785941408726, penalty=l2, solver=sag;, score=0.868 total time=   4.1s
# [CV 4/5] END C=1.1685785941408726, penalty=l2, solver=sag;, score=0.869 total time=   4.2s
# [CV 2/5] END C=0.7986951286334389, penalty=l1, solver=saga;, score=0.869 total time=   3.2s
# [CV 5/5] END C=1.1685785941408726, penalty=l2, solver=sag;, score=0.871 total time=   4.4s
# [CV 1/5] END C=0.13755408446087358, penalty=l2, solver=newton-cg;, score=0.869 total time=   1.0s
# [CV 1/5] END C=0.7986951286334389, penalty=l1, solver=saga;, score=0.869 total time=   3.8s
# [CV 4/5] END C=0.13755408446087358, penalty=l2, solver=newton-cg;, score=0.869 total time=   0.9s
# [CV 2/5] END C=0.13755408446087358, penalty=l2, solver=newton-cg;, score=0.869 total time=   1.1s
# [CV 3/5] END C=0.13755408446087358, penalty=l2, solver=newton-cg;, score=0.868 total time=   1.0s
# [CV 5/5] END C=0.13755408446087358, penalty=l2, solver=newton-cg;, score=0.871 total time=   0.8s
# [CV 3/5] END C=0.7986951286334389, penalty=l1, solver=saga;, score=0.868 total time=   4.1s
# [CV 5/5] END C=0.7986951286334389, penalty=l1, solver=saga;, score=0.871 total time=   4.1s
# [CV 1/5] END C=1.2468443043576438, penalty=l2, solver=lbfgs;, score=0.869 total time=   0.6s
# [CV 2/5] END C=1.2468443043576438, penalty=l2, solver=lbfgs;, score=0.869 total time=   0.4s
# [CV 3/5] END C=1.2468443043576438, penalty=l2, solver=lbfgs;, score=0.868 total time=   0.4s
# [CV 4/5] END C=0.7986951286334389, penalty=l1, solver=saga;, score=0.869 total time=   4.5s
# [CV 4/5] END C=1.2468443043576438, penalty=l2, solver=lbfgs;, score=0.869 total time=   0.8s
# [CV 5/5] END C=1.2468443043576438, penalty=l2, solver=lbfgs;, score=0.871 total time=   0.8s
# [CV 1/5] END C=2.7369321060486276, penalty=l1, solver=saga;, score=0.869 total time=   3.8s
# [CV 2/5] END C=2.1868411173731186, penalty=l2, solver=newton-cg;, score=0.869 total time=   0.9s
# [CV 1/5] END C=2.1868411173731186, penalty=l2, solver=newton-cg;, score=0.869 total time=   1.1s
# [CV 2/5] END C=0.4881529393791153, penalty=l1, solver=saga;, score=0.869 total time=   3.9s
# [CV 3/5] END C=0.4881529393791153, penalty=l1, solver=saga;, score=0.868 total time=   3.8s
# [CV 4/5] END C=2.7369321060486276, penalty=l1, solver=saga;, score=0.869 total time=   4.2s
# [CV 3/5] END C=2.1868411173731186, penalty=l2, solver=newton-cg;, score=0.868 total time=   1.3s
# [CV 2/5] END C=2.7369321060486276, penalty=l1, solver=saga;, score=0.869 total time=   4.3s
# [CV 3/5] END C=2.7369321060486276, penalty=l1, solver=saga;, score=0.868 total time=   4.3s
# [CV 5/5] END C=2.7369321060486276, penalty=l1, solver=saga;, score=0.871 total time=   4.3s
# [CV 4/5] END C=0.4881529393791153, penalty=l1, solver=saga;, score=0.869 total time=   4.0s
# [CV 5/5] END C=0.4881529393791153, penalty=l1, solver=saga;, score=0.871 total time=   4.3s
# [CV 4/5] END C=2.1868411173731186, penalty=l2, solver=newton-cg;, score=0.869 total time=   1.5s
# [CV 5/5] END C=2.1868411173731186, penalty=l2, solver=newton-cg;, score=0.871 total time=   1.6s
# [CV 5/5] END C=1.0351199264000677, penalty=l2, solver=saga;, score=0.871 total time=   3.3s
# [CV 3/5] END C=1.0351199264000677, penalty=l2, solver=saga;, score=0.868 total time=   3.4s
# [CV 1/5] END C=0.4881529393791153, penalty=l1, solver=saga;, score=0.869 total time=   5.8s
# [CV 4/5] END C=1.0351199264000677, penalty=l2, solver=saga;, score=0.869 total time=   3.9s
# [CV 2/5] END C=1.0351199264000677, penalty=l2, solver=saga;, score=0.869 total time=   4.2s
# [CV 1/5] END C=1.0351199264000677, penalty=l2, solver=saga;, score=0.869 total time=   4.7s
# [CV 1/5] END C=3.8783385110582342, penalty=l2, solver=saga;, score=0.869 total time=   3.1s
# [CV 5/5] END C=3.7579957662567565, penalty=l2, solver=saga;, score=0.871 total time=   2.6s
# [CV 2/5] END C=3.8783385110582342, penalty=l2, solver=saga;, score=0.869 total time=   3.2s
# [CV 4/5] END C=3.8783385110582342, penalty=l2, solver=saga;, score=0.869 total time=   3.4s
# [CV 4/5] END C=3.7579957662567565, penalty=l2, solver=saga;, score=0.869 total time=   3.0s
# [CV 5/5] END C=3.8783385110582342, penalty=l2, solver=saga;, score=0.871 total time=   3.4s
# [CV 3/5] END C=3.8783385110582342, penalty=l2, solver=saga;, score=0.868 total time=   3.6s
# [CV 1/5] END C=3.7579957662567565, penalty=l2, solver=saga;, score=0.869 total time=   3.4s
# [CV 1/5] END C=0.18090915564215226, penalty=l2, solver=newton-cg;, score=0.869 total time=   0.9s
# [CV 2/5] END C=0.18090915564215226, penalty=l2, solver=newton-cg;, score=0.869 total time=   0.9s
# [CV 3/5] END C=3.7579957662567565, penalty=l2, solver=saga;, score=0.868 total time=   3.7s
# [CV 3/5] END C=0.18090915564215226, penalty=l2, solver=newton-cg;, score=0.868 total time=   1.0s
# [CV 4/5] END C=0.18090915564215226, penalty=l2, solver=newton-cg;, score=0.869 total time=   0.9s
# [CV 5/5] END C=0.18090915564215226, penalty=l2, solver=newton-cg;, score=0.871 total time=   1.0s
# [CV 2/5] END C=3.7579957662567565, penalty=l2, solver=saga;, score=0.869 total time=   4.3s
# [CV 1/5] END C=3.3149500366077174, penalty=l2, solver=newton-cg;, score=0.869 total time=   0.9s
# [CV 2/5] END C=3.3149500366077174, penalty=l2, solver=newton-cg;, score=0.869 total time=   0.8s
# [CV 1/5] END C=0.353970008207678, penalty=l1, solver=saga;, score=0.869 total time=   3.4s
# [CV 1/5] END C=2.3915999152443406, penalty=l2, solver=sag;, score=0.869 total time=   4.6s
# [CV 3/5] END C=3.3149500366077174, penalty=l2, solver=newton-cg;, score=0.868 total time=   0.9s
# [CV 4/5] END C=3.3149500366077174, penalty=l2, solver=newton-cg;, score=0.869 total time=   0.9s
# [CV 1/5] END C=0.5636968998990506, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 2/5] END C=0.5636968998990506, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 3/5] END C=2.3915999152443406, penalty=l2, solver=sag;, score=0.868 total time=   4.4s
# [CV 3/5] END C=0.5636968998990506, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 4/5] END C=0.5636968998990506, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 5/5] END C=0.5636968998990506, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 1/5] END C=0.2982025747190833, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 2/5] END C=0.2982025747190833, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 3/5] END C=0.2982025747190833, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 4/5] END C=0.2982025747190833, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 5/5] END C=0.2982025747190833, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 5/5] END C=3.3149500366077174, penalty=l2, solver=newton-cg;, score=0.871 total time=   1.1s
# [CV 5/5] END C=2.3915999152443406, penalty=l2, solver=sag;, score=0.871 total time=   4.4s
# [CV 2/5] END C=2.3915999152443406, penalty=l2, solver=sag;, score=0.869 total time=   5.0s
# [CV 1/5] END C=1.123738038749523, penalty=l2, solver=newton-cg;, score=0.869 total time=   1.0s
# [CV 2/5] END C=1.123738038749523, penalty=l2, solver=newton-cg;, score=0.869 total time=   1.0s
# [CV 1/5] END C=0.022088468494409597, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 4/5] END C=2.3915999152443406, penalty=l2, solver=sag;, score=0.869 total time=   4.7s
# [CV 3/5] END C=0.022088468494409597, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 2/5] END C=0.022088468494409597, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 4/5] END C=0.022088468494409597, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 5/5] END C=0.022088468494409597, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 1/5] END C=2.8274293753904685, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 4/5] END C=1.123738038749523, penalty=l2, solver=newton-cg;, score=0.869 total time=   1.0s
# [CV 3/5] END C=2.8274293753904685, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 2/5] END C=2.8274293753904685, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 3/5] END C=1.123738038749523, penalty=l2, solver=newton-cg;, score=0.868 total time=   1.0s
# [CV 4/5] END C=2.8274293753904685, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 5/5] END C=2.8274293753904685, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 1/5] END C=3.085081386743783, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END C=3.085081386743783, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END C=3.085081386743783, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END C=3.085081386743783, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END C=3.085081386743783, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END C=0.353970008207678, penalty=l1, solver=saga;, score=0.869 total time=   4.2s
# [CV 5/5] END C=1.123738038749523, penalty=l2, solver=newton-cg;, score=0.871 total time=   0.9s
# [CV 4/5] END C=0.353970008207678, penalty=l1, solver=saga;, score=0.869 total time=   4.0s
# [CV 3/5] END C=0.353970008207678, penalty=l1, solver=saga;, score=0.868 total time=   4.7s
# [CV 5/5] END C=0.353970008207678, penalty=l1, solver=saga;, score=0.871 total time=   4.7s
# [CV 3/5] END C=1.554709158757928, penalty=l2, solver=sag;, score=0.868 total time=   3.8s
# [CV 2/5] END C=1.554709158757928, penalty=l2, solver=sag;, score=0.869 total time=   4.2s
# [CV 1/5] END C=1.554709158757928, penalty=l2, solver=sag;, score=0.869 total time=   4.3s
# [CV 2/5] END C=3.0889790771866297, penalty=l2, solver=saga;, score=0.869 total time=   2.4s
# [CV 4/5] END C=1.554709158757928, penalty=l2, solver=sag;, score=0.869 total time=   4.3s
# [CV 4/5] END C=3.0889790771866297, penalty=l2, solver=saga;, score=0.869 total time=   2.4s
# [CV 5/5] END C=3.0889790771866297, penalty=l2, solver=saga;, score=0.871 total time=   2.6s
# [CV 3/5] END C=3.0889790771866297, penalty=l2, solver=saga;, score=0.868 total time=   3.0s
# [CV 1/5] END C=3.0889790771866297, penalty=l2, solver=saga;, score=0.869 total time=   3.1s
# [CV 1/5] END C=3.452413703502374, penalty=l2, solver=saga;, score=0.869 total time=   2.7s
# [CV 1/5] END C=1.2439292868626488, penalty=l2, solver=newton-cg;, score=0.869 total time=   0.9s
# [CV 5/5] END C=1.554709158757928, penalty=l2, solver=sag;, score=0.871 total time=   5.2s
# [CV 2/5] END C=1.4338629141770904, penalty=l1, solver=saga;, score=0.869 total time=   3.1s
# [CV 2/5] END C=1.2439292868626488, penalty=l2, solver=newton-cg;, score=0.869 total time=   0.9s
# [CV 2/5] END C=3.452413703502374, penalty=l2, solver=saga;, score=0.869 total time=   3.3s
# [CV 1/5] END C=1.4338629141770904, penalty=l1, solver=saga;, score=0.869 total time=   3.4s
# [CV 1/5] END C=3.548850970305306, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 1/5] END C=2.9184247133522563, penalty=l2, solver=lbfgs;, score=0.869 total time=   0.5s
# [CV 2/5] END C=3.548850970305306, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 3/5] END C=3.548850970305306, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 2/5] END C=2.9184247133522563, penalty=l2, solver=lbfgs;, score=0.869 total time=   0.5s
# [CV 4/5] END C=3.548850970305306, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 5/5] END C=3.548850970305306, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 5/5] END C=1.4338629141770904, penalty=l1, solver=saga;, score=0.871 total time=   3.6s
# [CV 3/5] END C=2.9184247133522563, penalty=l2, solver=lbfgs;, score=0.868 total time=   0.6s
# [CV 4/5] END C=1.2439292868626488, penalty=l2, solver=newton-cg;, score=0.869 total time=   1.0s
# [CV 3/5] END C=1.4338629141770904, penalty=l1, solver=saga;, score=0.868 total time=   3.7s
# [CV 3/5] END C=3.452413703502374, penalty=l2, solver=saga;, score=0.868 total time=   3.6s
# [CV 4/5] END C=3.452413703502374, penalty=l2, solver=saga;, score=0.869 total time=   3.1s
# [CV 5/5] END C=3.452413703502374, penalty=l2, solver=saga;, score=0.871 total time=   2.9s
# [CV 4/5] END C=2.9184247133522563, penalty=l2, solver=lbfgs;, score=0.869 total time=   0.5s
# [CV 5/5] END C=2.9184247133522563, penalty=l2, solver=lbfgs;, score=0.871 total time=   0.5s
# [CV 3/5] END C=1.2439292868626488, penalty=l2, solver=newton-cg;, score=0.868 total time=   1.2s
# [CV 1/5] END C=3.083868719818244, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 2/5] END C=3.083868719818244, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 3/5] END C=3.083868719818244, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 4/5] END C=3.083868719818244, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 4/5] END C=1.4338629141770904, penalty=l1, solver=saga;, score=0.869 total time=   3.9s
# [CV 5/5] END C=3.083868719818244, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 5/5] END C=1.2439292868626488, penalty=l2, solver=newton-cg;, score=0.871 total time=   1.1s
# [CV 1/5] END C=2.0909313175279762, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END C=2.0909313175279762, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END C=2.0909313175279762, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END C=2.0909313175279762, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END C=0.10167650697638075, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 5/5] END C=2.0909313175279762, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END C=0.10167650697638075, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 4/5] END C=0.10167650697638075, penalty=l1, solver=sag;, score=nan total time=   0.1s
# [CV 1/5] END C=0.125716742746937, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 5/5] END C=0.10167650697638075, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 2/5] END C=0.10167650697638075, penalty=l1, solver=sag;, score=nan total time=   0.1s
# [CV 2/5] END C=0.125716742746937, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 3/5] END C=0.125716742746937, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 4/5] END C=0.125716742746937, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 5/5] END C=0.125716742746937, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 3/5] END C=1.3235920994105967, penalty=l2, solver=sag;, score=0.868 total time=   3.8s
# [CV 1/5] END C=3.630265895704372, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 2/5] END C=3.630265895704372, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 3/5] END C=3.630265895704372, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 4/5] END C=3.630265895704372, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 5/5] END C=3.630265895704372, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 1/5] END C=1.641531692142519, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 2/5] END C=1.641531692142519, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 1/5] END C=1.3235920994105967, penalty=l2, solver=sag;, score=0.869 total time=   4.3s
# [CV 3/5] END C=1.641531692142519, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 4/5] END C=1.641531692142519, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 5/5] END C=1.641531692142519, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 2/5] END C=1.3235920994105967, penalty=l2, solver=sag;, score=0.869 total time=   4.2s
# [CV 4/5] END C=1.3235920994105967, penalty=l2, solver=sag;, score=0.869 total time=   4.2s
# [CV 5/5] END C=1.3235920994105967, penalty=l2, solver=sag;, score=0.871 total time=   4.3s
# [CV 4/5] END C=1.2574239243053067, penalty=l2, solver=saga;, score=0.869 total time=   2.8s
# [CV 5/5] END C=1.2574239243053067, penalty=l2, solver=saga;, score=0.871 total time=   3.0s
# [CV 3/5] END C=1.2574239243053067, penalty=l2, solver=saga;, score=0.868 total time=   3.4s
# [CV 2/5] END C=1.2574239243053067, penalty=l2, solver=saga;, score=0.869 total time=   3.4s
# [CV 2/5] END C=3.0431401944675898, penalty=l2, solver=sag;, score=0.869 total time=   3.9s
# [CV 4/5] END C=0.4783769837532068, penalty=l2, solver=sag;, score=0.869 total time=   4.1s
# [CV 1/5] END C=3.7187906093702923, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END C=3.0431401944675898, penalty=l2, solver=sag;, score=0.868 total time=   4.1s
# [CV 2/5] END C=3.7187906093702923, penalty=l1, solver=lbfgs;, score=nan total time=   0.1s
# [CV 3/5] END C=3.7187906093702923, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END C=1.2574239243053067, penalty=l2, solver=saga;, score=0.869 total time=   3.8s
# [CV 4/5] END C=3.7187906093702923, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END C=3.7187906093702923, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END C=0.4783769837532068, penalty=l2, solver=sag;, score=0.871 total time=   4.3s
# [CV 1/5] END C=0.4783769837532068, penalty=l2, solver=sag;, score=0.869 total time=   4.4s
# [CV 4/5] END C=3.0431401944675898, penalty=l2, solver=sag;, score=0.869 total time=   4.4s
# [CV 2/5] END C=0.4783769837532068, penalty=l2, solver=sag;, score=0.869 total time=   4.6s
# [CV 5/5] END C=3.0431401944675898, penalty=l2, solver=sag;, score=0.871 total time=   4.4s
# [CV 3/5] END C=0.4783769837532068, penalty=l2, solver=sag;, score=0.868 total time=   5.0s
# [CV 1/5] END C=3.0431401944675898, penalty=l2, solver=sag;, score=0.869 total time=   5.3s
# [CV 1/5] END C=0.9151926619664899, penalty=l2, solver=sag;, score=0.869 total time=   4.1s
# [CV 2/5] END C=1.159005811655072, penalty=l2, solver=saga;, score=0.869 total time=   2.8s
# [CV 1/5] END C=1.159005811655072, penalty=l2, solver=saga;, score=0.869 total time=   3.1s
# [CV 3/5] END C=0.9151926619664899, penalty=l2, solver=sag;, score=0.868 total time=   4.3s
# [CV 3/5] END C=1.159005811655072, penalty=l2, solver=saga;, score=0.868 total time=   2.8s
# [CV 5/5] END C=1.159005811655072, penalty=l2, solver=saga;, score=0.871 total time=   2.7s
# [CV 4/5] END C=0.9151926619664899, penalty=l2, solver=sag;, score=0.869 total time=   4.1s
# [CV 5/5] END C=0.9151926619664899, penalty=l2, solver=sag;, score=0.871 total time=   4.1s
# [CV 2/5] END C=0.9151926619664899, penalty=l2, solver=sag;, score=0.869 total time=   4.7s
# [CV 3/5] END C=2.533615026041694, penalty=l2, solver=saga;, score=0.868 total time=   2.8s
# [CV 4/5] END C=1.159005811655072, penalty=l2, solver=saga;, score=0.869 total time=   3.3s
# [CV 1/5] END C=1.2720138998874555, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 2/5] END C=1.2720138998874555, penalty=l1, solver=newton-cg;, score=nan total time=   0.1s
# [CV 3/5] END C=1.2720138998874555, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 4/5] END C=1.2720138998874555, penalty=l1, solver=newton-cg;, score=nan total time=   0.1s
# [CV 1/5] END C=3.22976062065625, penalty=l2, solver=newton-cg;, score=0.869 total time=   0.8s
# [CV 4/5] END C=2.533615026041694, penalty=l2, solver=saga;, score=0.869 total time=   3.2s
# [CV 5/5] END C=1.2720138998874555, penalty=l1, solver=newton-cg;, score=nan total time=   0.1s
# [CV 1/5] END C=2.533615026041694, penalty=l2, solver=saga;, score=0.869 total time=   3.4s
# [CV 2/5] END C=2.533615026041694, penalty=l2, solver=saga;, score=0.869 total time=   3.4s
# [CV 2/5] END C=3.22976062065625, penalty=l2, solver=newton-cg;, score=0.869 total time=   1.0s
# [CV 1/5] END C=3.2720590636899725, penalty=l1, solver=sag;, score=nan total time=   0.1s
# [CV 2/5] END C=3.2720590636899725, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 3/5] END C=3.2720590636899725, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 4/5] END C=3.22976062065625, penalty=l2, solver=newton-cg;, score=0.869 total time=   1.1s
# [CV 4/5] END C=3.2720590636899725, penalty=l1, solver=sag;, score=nan total time=   0.1s
# [CV 3/5] END C=3.22976062065625, penalty=l2, solver=newton-cg;, score=0.868 total time=   1.1s
# [CV 5/5] END C=3.2720590636899725, penalty=l1, solver=sag;, score=nan total time=   0.1s
# [CV 3/5] END C=3.214688307596458, penalty=l2, solver=saga;, score=0.868 total time=   3.6s
# [CV 2/5] END C=3.214688307596458, penalty=l2, solver=saga;, score=0.869 total time=   3.6s
# [CV 5/5] END C=3.22976062065625, penalty=l2, solver=newton-cg;, score=0.871 total time=   1.2s
# [CV 4/5] END C=3.214688307596458, penalty=l2, solver=saga;, score=0.869 total time=   3.4s
# [CV 1/5] END C=1.669644012595116, penalty=l1, solver=newton-cg;, score=nan total time=   0.1s
# [CV 2/5] END C=1.669644012595116, penalty=l1, solver=newton-cg;, score=nan total time=   0.1s
# [CV 3/5] END C=1.669644012595116, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 4/5] END C=1.669644012595116, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 5/5] END C=1.669644012595116, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 5/5] END C=3.214688307596458, penalty=l2, solver=saga;, score=0.871 total time=   3.2s
# [CV 1/5] END C=0.9117406501677667, penalty=l2, solver=newton-cg;, score=0.869 total time=   1.1s
# [CV 2/5] END C=0.9117406501677667, penalty=l2, solver=newton-cg;, score=0.869 total time=   1.1s
# [CV 1/5] END C=3.214688307596458, penalty=l2, solver=saga;, score=0.869 total time=   4.1s
# [CV 5/5] END C=2.533615026041694, penalty=l2, solver=saga;, score=0.871 total time=   4.4s
# [CV 3/5] END C=0.9117406501677667, penalty=l2, solver=newton-cg;, score=0.868 total time=   1.2s
# [CV 4/5] END C=0.9117406501677667, penalty=l2, solver=newton-cg;, score=0.869 total time=   1.4s
# [CV 5/5] END C=0.9117406501677667, penalty=l2, solver=newton-cg;, score=0.871 total time=   1.4s
# [CV 3/5] END C=3.570235993959911, penalty=l1, solver=saga;, score=0.868 total time=   3.2s
# [CV 2/5] END C=3.570235993959911, penalty=l1, solver=saga;, score=0.869 total time=   3.3s
# [CV 1/5] END C=3.570235993959911, penalty=l1, solver=saga;, score=0.869 total time=   3.9s
# [CV 4/5] END C=3.570235993959911, penalty=l1, solver=saga;, score=0.869 total time=   3.7s
# [CV 5/5] END C=3.570235993959911, penalty=l1, solver=saga;, score=0.871 total time=   3.8s
# [CV 1/5] END C=0.4794614693347312, penalty=l2, solver=saga;, score=0.869 total time=   2.9s
# [CV 1/5] END C=1.454518409517176, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END C=1.454518409517176, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END C=0.4794614693347312, penalty=l2, solver=saga;, score=0.871 total time=   2.9s
# [CV 3/5] END C=1.454518409517176, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END C=0.4794614693347312, penalty=l2, solver=saga;, score=0.869 total time=   3.0s
# [CV 2/5] END C=0.4794614693347312, penalty=l2, solver=saga;, score=0.869 total time=   3.1s
# [CV 4/5] END C=1.454518409517176, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END C=1.454518409517176, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END C=0.4794614693347312, penalty=l2, solver=saga;, score=0.868 total time=   3.2s
# [CV 2/5] END C=3.7716388156500766, penalty=l2, solver=saga;, score=0.869 total time=   3.2s
# [CV 3/5] END C=0.027808522124762813, penalty=l2, solver=sag;, score=0.868 total time=   3.9s
# [CV 1/5] END C=1.9889940235695418, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 2/5] END C=1.9889940235695418, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 2/5] END C=0.027808522124762813, penalty=l2, solver=sag;, score=0.869 total time=   4.0s
# [CV 3/5] END C=1.9889940235695418, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 1/5] END C=3.7716388156500766, penalty=l2, solver=saga;, score=0.869 total time=   3.3s
# [CV 4/5] END C=1.9889940235695418, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 3/5] END C=3.7716388156500766, penalty=l2, solver=saga;, score=0.868 total time=   3.3s
# [CV 1/5] END C=1.1393619775098704, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 5/5] END C=1.9889940235695418, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 2/5] END C=1.1393619775098704, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 3/5] END C=1.1393619775098704, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 4/5] END C=1.1393619775098704, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 5/5] END C=1.1393619775098704, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 1/5] END C=0.027808522124762813, penalty=l2, solver=sag;, score=0.869 total time=   4.1s
# [CV 5/5] END C=3.7716388156500766, penalty=l2, solver=saga;, score=0.871 total time=   3.1s
# [CV 4/5] END C=3.7716388156500766, penalty=l2, solver=saga;, score=0.869 total time=   3.2s
# [CV 5/5] END C=0.027808522124762813, penalty=l2, solver=sag;, score=0.871 total time=   4.0s
# [CV 4/5] END C=0.027808522124762813, penalty=l2, solver=sag;, score=0.869 total time=   4.3s
# [CV 1/5] END C=2.0751624869734644, penalty=l1, solver=saga;, score=0.869 total time=   3.5s
# [CV 2/5] END C=2.0751624869734644, penalty=l1, solver=saga;, score=0.869 total time=   3.5s
# [CV 2/5] END C=3.633063543866615, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END C=3.633063543866615, penalty=l1, solver=lbfgs;, score=nan total time=   0.1s
# [CV 3/5] END C=3.633063543866615, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END C=3.633063543866615, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END C=3.633063543866615, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END C=2.0751624869734644, penalty=l1, solver=saga;, score=0.868 total time=   3.3s
# [CV 5/5] END C=2.0751624869734644, penalty=l1, solver=saga;, score=0.871 total time=   3.2s
# [CV 4/5] END C=2.0751624869734644, penalty=l1, solver=saga;, score=0.869 total time=   3.5s
# [CV 1/5] END C=0.5795794883648924, penalty=l2, solver=lbfgs;, score=0.869 total time=   0.5s
# [CV 2/5] END C=0.5795794883648924, penalty=l2, solver=lbfgs;, score=0.869 total time=   0.5s
# [CV 3/5] END C=0.5795794883648924, penalty=l2, solver=lbfgs;, score=0.868 total time=   0.5s
# [CV 4/5] END C=0.5795794883648924, penalty=l2, solver=lbfgs;, score=0.869 total time=   0.4s
# [CV 5/5] END C=0.5795794883648924, penalty=l2, solver=lbfgs;, score=0.871 total time=   0.5s
# [CV 2/5] END C=2.4382573359195874, penalty=l2, solver=saga;, score=0.869 total time=   2.8s
# [CV 1/5] END C=0.2059150049999574, penalty=l1, solver=saga;, score=0.869 total time=   2.7s
# [CV 3/5] END C=2.4382573359195874, penalty=l2, solver=saga;, score=0.868 total time=   3.1s
# [CV 4/5] END C=3.849789179768445, penalty=l2, solver=sag;, score=0.869 total time=   3.6s
# [CV 2/5] END C=0.2059150049999574, penalty=l1, solver=saga;, score=0.869 total time=   3.3s
# [CV 4/5] END C=2.4382573359195874, penalty=l2, solver=saga;, score=0.869 total time=   3.6s
# [CV 1/5] END C=0.9505501759695987, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END C=2.4382573359195874, penalty=l2, solver=saga;, score=0.871 total time=   3.6s
# [CV 2/5] END C=0.9505501759695987, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END C=3.849789179768445, penalty=l2, solver=sag;, score=0.869 total time=   4.1s
# [CV 3/5] END C=0.9505501759695987, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END C=2.4382573359195874, penalty=l2, solver=saga;, score=0.869 total time=   3.7s
# [CV 4/5] END C=0.9505501759695987, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END C=0.2059150049999574, penalty=l1, solver=saga;, score=0.870 total time=   3.3s
# [CV 5/5] END C=0.9505501759695987, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END C=0.2059150049999574, penalty=l1, solver=saga;, score=0.869 total time=   3.7s
# [CV 5/5] END C=3.849789179768445, penalty=l2, solver=sag;, score=0.871 total time=   4.3s
# [CV 1/5] END C=2.534118843043579, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 2/5] END C=2.534118843043579, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 3/5] END C=2.534118843043579, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 3/5] END C=3.849789179768445, penalty=l2, solver=sag;, score=0.868 total time=   4.4s
# [CV 4/5] END C=2.534118843043579, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 5/5] END C=2.534118843043579, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 1/5] END C=0.3611590802176332, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 2/5] END C=0.3611590802176332, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 3/5] END C=0.3611590802176332, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 4/5] END C=0.3611590802176332, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 5/5] END C=0.3611590802176332, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 3/5] END C=0.2059150049999574, penalty=l1, solver=saga;, score=0.868 total time=   4.0s
# [CV 1/5] END C=1.471132530877013, penalty=l2, solver=lbfgs;, score=0.869 total time=   0.4s
# [CV 5/5] END C=1.471132530877013, penalty=l2, solver=lbfgs;, score=0.871 total time=   0.4s
# [CV 3/5] END C=1.471132530877013, penalty=l2, solver=lbfgs;, score=0.868 total time=   0.5s
# [CV 2/5] END C=1.471132530877013, penalty=l2, solver=lbfgs;, score=0.869 total time=   0.5s
# [CV 4/5] END C=1.471132530877013, penalty=l2, solver=lbfgs;, score=0.869 total time=   0.5s
# [CV 1/5] END C=3.849789179768445, penalty=l2, solver=sag;, score=0.869 total time=   5.0s
# [CV 2/5] END C=3.942601816442403, penalty=l2, solver=sag;, score=0.869 total time=   4.0s
# [CV 1/5] END C=2.7102574473691297, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END C=2.7102574473691297, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END C=2.7102574473691297, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END C=3.942601816442403, penalty=l2, solver=sag;, score=0.868 total time=   4.0s
# [CV 5/5] END C=3.942601816442403, penalty=l2, solver=sag;, score=0.871 total time=   3.7s
# [CV 4/5] END C=2.7102574473691297, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END C=2.7102574473691297, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END C=2.688542189623514, penalty=l1, solver=saga;, score=0.869 total time=   3.3s
# [CV 4/5] END C=3.942601816442403, penalty=l2, solver=sag;, score=0.869 total time=   4.0s
# [CV 3/5] END C=2.688542189623514, penalty=l1, solver=saga;, score=0.868 total time=   3.3s
# [CV 1/5] END C=2.688542189623514, penalty=l1, solver=saga;, score=0.869 total time=   3.7s
# [CV 4/5] END C=0.16310056621905566, penalty=l2, solver=saga;, score=0.869 total time=   2.4s
# [CV 4/5] END C=2.688542189623514, penalty=l1, solver=saga;, score=0.869 total time=   3.5s
# [CV 2/5] END C=0.16310056621905566, penalty=l2, solver=saga;, score=0.869 total time=   2.8s
# [CV 5/5] END C=2.688542189623514, penalty=l1, solver=saga;, score=0.871 total time=   3.8s
# [CV 1/5] END C=3.942601816442403, penalty=l2, solver=sag;, score=0.869 total time=   5.6s
# [CV 1/5] END C=0.16310056621905566, penalty=l2, solver=saga;, score=0.869 total time=   3.1s
# [CV 1/5] END C=1.2831202598869433, penalty=l2, solver=saga;, score=0.869 total time=   3.2s
# [CV 2/5] END C=2.5806911616377994, penalty=l2, solver=newton-cg;, score=0.869 total time=   0.9s
# [CV 1/5] END C=2.5806911616377994, penalty=l2, solver=newton-cg;, score=0.869 total time=   1.0s
# [CV 2/5] END C=1.2831202598869433, penalty=l2, solver=saga;, score=0.869 total time=   3.4s
# [CV 1/5] END C=3.746919954946938, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 2/5] END C=3.746919954946938, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 4/5] END C=3.746919954946938, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 3/5] END C=3.746919954946938, penalty=l1, solver=sag;, score=nan total time=   0.1s
# [CV 4/5] END C=2.5806911616377994, penalty=l2, solver=newton-cg;, score=0.869 total time=   0.9s
# [CV 1/5] END C=1.364265404201034, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END C=0.16310056621905566, penalty=l2, solver=saga;, score=0.871 total time=   3.1s
# [CV 3/5] END C=2.5806911616377994, penalty=l2, solver=newton-cg;, score=0.868 total time=   1.0s
# [CV 3/5] END C=1.364265404201034, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END C=1.364265404201034, penalty=l1, solver=lbfgs;, score=nan total time=   0.1s
# [CV 5/5] END C=3.746919954946938, penalty=l1, solver=sag;, score=nan total time=   0.1s
# [CV 4/5] END C=1.364265404201034, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END C=1.364265404201034, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END C=1.2831202598869433, penalty=l2, solver=saga;, score=0.869 total time=   4.1s
# [CV 1/5] END C=3.698774473114251, penalty=l2, solver=lbfgs;, score=0.869 total time=   0.5s
# [CV 2/5] END C=3.698774473114251, penalty=l2, solver=lbfgs;, score=0.869 total time=   0.6s
# [CV 3/5] END C=3.698774473114251, penalty=l2, solver=lbfgs;, score=0.868 total time=   0.6s
# [CV 4/5] END C=3.698774473114251, penalty=l2, solver=lbfgs;, score=0.869 total time=   0.6s
# [CV 5/5] END C=3.698774473114251, penalty=l2, solver=lbfgs;, score=0.871 total time=   0.6s
# [CV 3/5] END C=1.2831202598869433, penalty=l2, solver=saga;, score=0.868 total time=   4.4s
# [CV 5/5] END C=2.5806911616377994, penalty=l2, solver=newton-cg;, score=0.871 total time=   1.7s
# [CV 5/5] END C=1.2831202598869433, penalty=l2, solver=saga;, score=0.871 total time=   4.6s
# [CV 3/5] END C=0.16310056621905566, penalty=l2, solver=saga;, score=0.868 total time=   4.6s
# [CV 2/5] END C=2.048372233197124, penalty=l1, solver=saga;, score=0.869 total time=   3.5s
# [CV 4/5] END C=2.048372233197124, penalty=l1, solver=saga;, score=0.869 total time=   3.7s
# [CV 5/5] END C=2.048372233197124, penalty=l1, solver=saga;, score=0.871 total time=   3.8s
# [CV 3/5] END C=2.048372233197124, penalty=l1, solver=saga;, score=0.868 total time=   4.1s
# [CV 1/5] END C=2.048372233197124, penalty=l1, solver=saga;, score=0.869 total time=   4.2s
# [CV 1/5] END C=2.118602313424026, penalty=l2, solver=newton-cg;, score=0.869 total time=   0.9s
# [CV 2/5] END C=2.118602313424026, penalty=l2, solver=newton-cg;, score=0.869 total time=   1.0s
# [CV 3/5] END C=2.118602313424026, penalty=l2, solver=newton-cg;, score=0.868 total time=   1.0s
# [CV 4/5] END C=2.118602313424026, penalty=l2, solver=newton-cg;, score=0.869 total time=   1.0s
# [CV 5/5] END C=2.118602313424026, penalty=l2, solver=newton-cg;, score=0.871 total time=   0.9s
# [CV 2/5] END C=1.0317665108606224, penalty=l2, solver=saga;, score=0.869 total time=   3.1s
# [CV 1/5] END C=0.37241107122359685, penalty=l2, solver=newton-cg;, score=0.869 total time=   0.9s
# [CV 1/5] END C=1.0317665108606224, penalty=l2, solver=saga;, score=0.869 total time=   3.1s
# [CV 1/5] END C=3.601672228653322, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 2/5] END C=3.601672228653322, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 3/5] END C=3.601672228653322, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 4/5] END C=3.601672228653322, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 4/5] END C=2.763750952409864, penalty=l2, solver=sag;, score=0.869 total time=   4.1s
# [CV 5/5] END C=3.601672228653322, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 1/5] END C=1.3561191641948027, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 2/5] END C=1.3561191641948027, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 4/5] END C=1.3561191641948027, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 3/5] END C=1.3561191641948027, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 5/5] END C=1.3561191641948027, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 5/5] END C=1.0317665108606224, penalty=l2, solver=saga;, score=0.871 total time=   3.1s
# [CV 3/5] END C=1.0317665108606224, penalty=l2, solver=saga;, score=0.868 total time=   3.2s
# [CV 3/5] END C=2.763750952409864, penalty=l2, solver=sag;, score=0.868 total time=   4.3s
# [CV 4/5] END C=1.0317665108606224, penalty=l2, solver=saga;, score=0.869 total time=   3.3s
# [CV 2/5] END C=0.37241107122359685, penalty=l2, solver=newton-cg;, score=0.869 total time=   0.8s
# [CV 2/5] END C=2.763750952409864, penalty=l2, solver=sag;, score=0.869 total time=   4.4s
# [CV 1/5] END C=2.763750952409864, penalty=l2, solver=sag;, score=0.869 total time=   4.5s
# [CV 3/5] END C=0.37241107122359685, penalty=l2, solver=newton-cg;, score=0.868 total time=   0.9s
# [CV 4/5] END C=0.37241107122359685, penalty=l2, solver=newton-cg;, score=0.869 total time=   0.9s
# [CV 5/5] END C=0.37241107122359685, penalty=l2, solver=newton-cg;, score=0.871 total time=   0.9s
# [CV 5/5] END C=2.763750952409864, penalty=l2, solver=sag;, score=0.871 total time=   4.7s
# [CV 1/5] END C=3.2688888008048633, penalty=l1, solver=saga;, score=0.869 total time=   3.7s
# [CV 5/5] END C=3.2688888008048633, penalty=l1, solver=saga;, score=0.871 total time=   3.3s
# [CV 2/5] END C=3.2688888008048633, penalty=l1, solver=saga;, score=0.869 total time=   3.6s
# [CV 4/5] END C=3.2688888008048633, penalty=l1, solver=saga;, score=0.869 total time=   3.6s
# [CV 1/5] END C=3.548345697060469, penalty=l2, solver=newton-cg;, score=0.869 total time=   0.8s
# [CV 2/5] END C=3.548345697060469, penalty=l2, solver=newton-cg;, score=0.869 total time=   0.8s
# [CV 4/5] END C=3.548345697060469, penalty=l2, solver=newton-cg;, score=0.869 total time=   0.8s
# [CV 3/5] END C=3.548345697060469, penalty=l2, solver=newton-cg;, score=0.868 total time=   0.8s
# [CV 5/5] END C=3.548345697060469, penalty=l2, solver=newton-cg;, score=0.871 total time=   0.7s
# [CV 3/5] END C=3.2688888008048633, penalty=l1, solver=saga;, score=0.868 total time=   3.8s
# [CV 4/5] END C=2.9038227154809575, penalty=l1, solver=saga;, score=0.869 total time=   2.1s
# [CV 2/5] END C=2.9038227154809575, penalty=l1, solver=saga;, score=0.869 total time=   2.3s
# [CV 3/5] END C=2.9038227154809575, penalty=l1, solver=saga;, score=0.868 total time=   2.4s
# [CV 1/5] END C=2.9038227154809575, penalty=l1, solver=saga;, score=0.869 total time=   2.5s
# [CV 5/5] END C=2.9038227154809575, penalty=l1, solver=saga;, score=0.871 total time=   2.5s
# RandomizedSearchCV(cv=5, estimator=LogisticRegression(max_iter=5000),
#                    n_iter=100, n_jobs=-1,
#                    param_distributions={'C': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x7fcbba9b1100>,
#                                         'penalty': ['l1', 'l2'],
#                                         'solver': ['newton-cg', 'lbfgs', 'sag',
#                                                    'saga']},
#                    random_state=42, verbose=3)

# %%
# Summarize the Performance of the Best parameters
print(f"---------------------------------------------")
print(f"Best Parameters for Logistic Regression: {random_search.best_params_}")
print(f"---------------------------------------------\n\n")

# Best model
best_log_reg = random_search.best_estimator_

# Make predictions on the test set
y_pred_log_reg = best_log_reg.predict(X_test)

best_data = X_test, y_test, y_pred_log_reg
mlanlys.model_performance_metrics(best_log_reg, best_data, "Best Logistic Regression")
# Out:
# ---------------------------------------------
# Best Parameters for Logistic Regression: {'C': 1.4338629141770904, 'penalty': 'l1', 'solver': 'saga'}
# ---------------------------------------------
#
#
# ------------------------------------------------------------------------
# ---------- Best Logistic Regressioning Data Performance
# ------------------------------------------------------------------------
# Confusion Matrix
# [[52444  1070]
#  [ 7003  1252]]
#
# -----------------------
# Best Logistic Regression score: 0.8693
# Balanced Accuracy Score: 0.5658
# ROC AUC Score: 0.8241
# Mean Squared Error: 0.1307
# ------------------------------
# --- Classification values
# ------------------------------
# Accuracy: 0.8693
# Precision: 0.5392
# Recall: 0.1517
# F1-score: 0.2368
# Specificity: 0.98
# False Positive Rate: 0.02
# Matthews Correlation Coefficient: 0.2356
#
# -----------------------
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.98      0.93     53514
#          1.0       0.54      0.15      0.24      8255
#
#     accuracy                           0.87     61769
#    macro avg       0.71      0.57      0.58     61769
# weighted avg       0.84      0.87      0.84     61769
# {'model': 'LogisticRegression',
#  'slice': 'Best Logistic Regression',
#  'score': 0.8693,
#  'balanced_accuracy': 0.5658,
#  'roc_auc_score': 0.8241,
#  'Mean Squared Error': 0.1307,
#  'Accuracy': 0.8693,
#  'Precision': 0.5392,
#  'Recall': 0.1517,
#  'F1-score': 0.2368,
#  'Specificity': 0.98,
#  'False Positive Rate': 0.02,
#  'Matthews Correlation Coefficient': 0.2356}

# %%
# Model without optimization
X_train, X_test, y_train, y_test = prepared_data

model = LogisticRegression()
# Train the model
model = model.fit(X_train, y_train)

y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

test_data = [ X_test, y_test, y_test_pred]

mlanlys.model_performance_metrics(model, test_data, "Original Logistic Regression" )
# Out:
# ------------------------------------------------------------------------
# ---------- Original Logistic Regressioning Data Performance
# ------------------------------------------------------------------------
# Confusion Matrix
# [[52571  1020]
#  [ 6962  1216]]
#
# -----------------------
# Original Logistic Regression score: 0.8708
# Balanced Accuracy Score: 0.5648
# ROC AUC Score: 0.825
# Mean Squared Error: 0.1292
# ------------------------------
# --- Classification values
# ------------------------------
# Accuracy: 0.8708
# Precision: 0.5438
# Recall: 0.1487
# F1-score: 0.2335
# Specificity: 0.981
# False Positive Rate: 0.019
# Matthews Correlation Coefficient: 0.2353
#
# -----------------------
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.98      0.93     53591
#          1.0       0.54      0.15      0.23      8178
#
#     accuracy                           0.87     61769
#    macro avg       0.71      0.56      0.58     61769
# weighted avg       0.84      0.87      0.84     61769
# {'model': 'LogisticRegression',
#  'slice': 'Original Logistic Regression',
#  'score': 0.8708,
#  'balanced_accuracy': 0.5648,
#  'roc_auc_score': 0.825,
#  'Mean Squared Error': 0.1292,
#  'Accuracy': 0.8708,
#  'Precision': 0.5438,
#  'Recall': 0.1487,
#  'F1-score': 0.2335,
#  'Specificity': 0.981,
#  'False Positive Rate': 0.019,
#  'Matthews Correlation Coefficient': 0.2353}

# %% [markdown]
# ---
#
# ## 4. Conclusions
#
# ---
